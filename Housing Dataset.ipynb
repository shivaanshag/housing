# %%
import tensorflow as tf
import numpy as np
import pandas as pd
#import matplotlib as plt1
#import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
housing= pd.read_csv('C:/Users/Sanjay/Documents/Jupyter Notebooks/Tensorflow-Bootcamp-master/02-TensorFlow-Basics/cal_housing_clean.csv')

# %%
housing.head()
from sklearn.preprocessing import MinMaxScaler

# %%
y_val=housing['medianHouseValue']

# %%
x_data=housing.drop('medianHouseValue',axis=1)

# %%
 X_train, X_test, y_train, y_test =train_test_split(x_data,y_val,test_size=0.3,random_state=101)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = pd.DataFrame(data=scaler.transform(X_train),columns=X_train.columns, index=X_train.index )

# %%
X_test = pd.DataFrame(data=scaler.transform(X_test),columns=X_test.columns, index=X_test.index )

# %%
housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
age = tf.feature_column.numeric_column('housingMedianAge')
rooms = tf.feature_column.numeric_column('totalRooms')
bedrooms = tf.feature_column.numeric_column('totalBedrooms')
pop = tf.feature_column.numeric_column('population')
households = tf.feature_column.numeric_column('households')
income = tf.feature_column.numeric_column('medianIncome')

# %%
feat_cols = [ age,rooms,bedrooms,pop,households,income]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train ,batch_size=10,num_epochs=1000,
                                            shuffle=True)

# %%
model = tf.estimator.DNNRegressor(hidden_units=[6,10,6,10,6],feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Sanjay\AppData\Local\Temp\tmp3xgjfgl8
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Sanjay\\AppData\\Local\\Temp\\tmp3xgjfgl8', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001E66A811860>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=50000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Sanjay\AppData\Local\Temp\tmp3xgjfgl8\model.ckpt.
# INFO:tensorflow:loss = 618072100000.0, step = 1
# INFO:tensorflow:global_step/sec: 763.439
# INFO:tensorflow:loss = 269679380000.0, step = 101 (0.131 sec)
# INFO:tensorflow:global_step/sec: 1143.68
# INFO:tensorflow:loss = 132803790000.0, step = 201 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1205.51
# INFO:tensorflow:loss = 42778526000.0, step = 301 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1002.78
# INFO:tensorflow:loss = 100622180000.0, step = 401 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1000.15
# INFO:tensorflow:loss = 168057750000.0, step = 501 (0.099 sec)
# INFO:tensorflow:global_step/sec: 1124.54
# ...

# %%
predict_input_func= tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
pred_gen = model.predict(predict_input_func)

# %%
predictions = list(pred_gen)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Sanjay\AppData\Local\Temp\tmp3xgjfgl8\model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# [{'predictions': array([302503.56], dtype=float32)},
#  {'predictions': array([522694.47], dtype=float32)},
#  {'predictions': array([160690.69], dtype=float32)},
#  {'predictions': array([191463.92], dtype=float32)},
#  {'predictions': array([455899.66], dtype=float32)},
#  {'predictions': array([164182.98], dtype=float32)},
#  {'predictions': array([203652.7], dtype=float32)},
#  {'predictions': array([185570.7], dtype=float32)},
#  {'predictions': array([271088.72], dtype=float32)},
#  {'predictions': array([303099.62], dtype=float32)},
#  {'predictions': array([189934.16], dtype=float32)},
#  {'predictions': array([190234.12], dtype=float32)},
#  {'predictions': array([164466.], dtype=float32)},
#  {'predictions': array([155748.17], dtype=float32)},
#  {'predictions': array([311397.34], dtype=float32)},
#  {'predictions': array([189270.19], dtype=float32)},
#  {'predictions': array([158787.61], dtype=float32)},
#  {'predictions': array([196391.28], dtype=float32)},
# ...

# %%
final_pred=[]

for pred in predictions:
    final_pred.append(pred['predictions'])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,final_pred)**0.5
# Out:
# 78345.04205053904
